# %%
# If you are running Databricks Runtime version 7.1 or above, uncomment this line and run this cell:
# %pip install mlflow
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: mlflow in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (1.22.0)
# Requirement already satisfied: pytz in /databricks/python3/lib/python3.8/site-packages (from mlflow) (2020.5)
# Requirement already satisfied: Flask in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (2.0.2)
# Requirement already satisfied: sqlalchemy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (1.4.28)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.8/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: sqlparse>=0.3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (0.4.2)
# Requirement already satisfied: gitpython>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (3.1.24)
# Requirement already satisfied: alembic<=1.4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (1.4.1)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.8/site-packages (from mlflow) (1.19.2)
# Requirement already satisfied: databricks-cli>=0.8.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (0.16.2)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.8/site-packages (from mlflow) (20.9)
# Requirement already satisfied: protobuf>=3.7.0 in /databricks/python3/lib/python3.8/site-packages (from mlflow) (3.17.2)
# Requirement already satisfied: requests>=2.17.3 in /databricks/python3/lib/python3.8/site-packages (from mlflow) (2.25.1)
# Requirement already satisfied: cloudpickle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (2.0.0)
# Requirement already satisfied: click>=7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (8.0.3)
# Requirement already satisfied: gunicorn in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (20.1.0)
# Requirement already satisfied: docker>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (5.0.3)
# Requirement already satisfied: querystring-parser in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: pyyaml>=5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (6.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (4.8.2)
# Requirement already satisfied: entrypoints in /databricks/python3/lib/python3.8/site-packages (from mlflow) (0.3)
# Requirement already satisfied: prometheus-flask-exporter in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from mlflow) (0.18.6)
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow) (2.8.1)
# Requirement already satisfied: python-editor>=0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow) (1.0.4)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow) (1.1.6)
# Requirement already satisfied: six>=1.10.0 in /databricks/python3/lib/python3.8/site-packages (from databricks-cli>=0.8.7->mlflow) (1.15.0)
# Requirement already satisfied: tabulate>=0.7.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from databricks-cli>=0.8.7->mlflow) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from docker>=4.0.0->mlflow) (1.2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from gitpython>=2.1.0->mlflow) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from gitpython>=2.1.0->mlflow) (4.0.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow) (3.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests>=2.17.3->mlflow) (2.10)
# Requirement already satisfied: greenlet!=0.4.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from sqlalchemy->mlflow) (1.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from Flask->mlflow) (2.0.2)
# Requirement already satisfied: Jinja2>=3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from Flask->mlflow) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from Flask->mlflow) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/lib/python3.8/site-packages (from Jinja2>=3.0->Flask->mlflow) (2.0.1)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.8/dist-packages (from gunicorn->mlflow) (52.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /databricks/python3/lib/python3.8/site-packages (from packaging->mlflow) (2.4.7)
# Requirement already satisfied: prometheus-client in /databricks/python3/lib/python3.8/site-packages (from prometheus-flask-exporter->mlflow) (0.10.1)
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-0f945cec-d43d-4747-9cb2-03c4ce238594/bin/python -m pip install --upgrade pip' command.
# Python interpreter will be restarted.

# %%
from pyspark.sql import SparkSession
from pyspark.ml.tuning import CrossValidator ,ParamGridBuilder 
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator
import mlflow
import mlflow.sklearn

# %%
#1st step is to create session and read data
Spark = SparkSession.builder.appName('recommendation').getOrCreate
sparkDF = spark.read.csv("/FileStore/tables/ratings.csv", header="true", inferSchema="true")
sparkDF.printSchema()
# Out:
# root
#  |-- UserID: integer (nullable = true)
#  |-- MovieID: integer (nullable = true)
#  |-- Rating: integer (nullable = true)
#  |-- Timestamp: integer (nullable = true)

# %%
sparkDF.show()
# Out:
# +------+-------+------+---------+
# |UserID|MovieID|Rating|Timestamp|
# +------+-------+------+---------+
# |     1|   1193|     5|978300760|
# |     1|    661|     3|978302109|
# |     1|    914|     3|978301968|
# |     1|   3408|     4|978300275|
# |     1|   2355|     5|978824291|
# |     1|   1197|     3|978302268|
# |     1|   1287|     5|978302039|
# |     1|   2804|     5|978300719|
# |     1|    594|     4|978302268|
# |     1|    919|     4|978301368|
# |     1|    595|     5|978824268|
# |     1|    938|     4|978301752|
# |     1|   2398|     4|978302281|
# |     1|   2918|     4|978302124|
# |     1|   1035|     5|978301753|
# |     1|   2791|     4|978302188|
# |     1|   2687|     3|978824268|
# |     1|   2018|     4|978301777|
# |     1|   3105|     5|978301713|
# |     1|   2797|     4|978302039|
# +------+-------+------+---------+
# only showing top 20 rows

# %%
#2nd step is to spilt data ro train and test
train, test = sparkDF.randomSplit([0.7 , 0.3])

# %%
#3rd step is to make als object
als  = ALS(userCol='UserID', itemCol='MovieID', seed=None, ratingCol='Rating', nonnegative=False)

# %%
#4th step: Parameter Grid
param_grid = ParamGridBuilder().addGrid(als.rank , [10, 20]).addGrid(als.maxIter , [20, 30]).build()

# %%
#5th step create evaluator
evaluator = RegressionEvaluator(labelCol="Rating", predictionCol="prediction")

# %%
#6th step cross validation
cv = CrossValidator(estimator= als , estimatorParamMaps= param_grid , evaluator = evaluator, numFolds = 3)

# %%
#7th step traing cv
model = cv.fit(train)
# Out:
# MLlib will automatically track trials in MLflow. After your tuning fit() call has completed, view the MLflow UI to see logged runs.

# %%
#8th step: make prediction
predictions = model.transform(test)
predictions.show()
# Out:
# +------+-------+------+----------+----------+
# |UserID|MovieID|Rating| Timestamp|prediction|
# +------+-------+------+----------+----------+
# |   148|   1580|     4| 977333525|   4.19132|
# |   148|   2122|     4| 979576798| 2.5385976|
# |   148|   2142|     4| 979578765| 3.4822428|
# |   148|   2366|     5| 977333254|  3.536327|
# |   463|   1580|     1| 976227202|  2.823757|
# |   471|   3175|     5| 976224710| 3.6693158|
# |  1088|   1591|     1| 974936438| 2.3341706|
# |   392|   1645|     4| 976550402|  3.134005|
# |   392|   1959|     4| 976552172| 3.2426915|
# |   858|   1580|     3| 975345152| 3.9262373|
# |   897|   1645|     3| 975222773| 3.2163181|
# |    31|   2366|     5| 978120364| 3.6254513|
# |   516|   1580|     3| 976280139| 3.0079026|
# |  1139|   1645|     3| 974877900| 3.4581625|
# |   137|   1645|     4|1000868305| 3.5603244|
# |   251|   1580|     4| 976715892| 3.5030975|
# |   808|   2122|     3| 975393329| 2.6154156|
# |    53|   3175|     5| 977949217|  4.472388|
# |   970|    463|     3| 980625253| 2.8023136|
# |   970|   1591|     2| 975978523| 2.2265937|
# +------+-------+------+----------+----------+
# only showing top 20 rows

# %%
predictions = predictions.dropna()

# %%
display(predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>UserID</th><th>MovieID</th><th>Rating</th><th>Timestamp</th><th>prediction</th></tr></thead><tbody><tr><td>148</td><td>1580</td><td>4</td><td>977333525</td><td>4.19132</td></tr><tr><td>148</td><td>2122</td><td>4</td><td>979576798</td><td>2.5385976</td></tr><tr><td>148</td><td>2142</td><td>4</td><td>979578765</td><td>3.4822428</td></tr><tr><td>148</td><td>2366</td><td>5</td><td>977333254</td><td>3.536327</td></tr><tr><td>463</td><td>1580</td><td>1</td><td>976227202</td><td>2.823757</td></tr><tr><td>471</td><td>3175</td><td>5</td><td>976224710</td><td>3.6693158</td></tr><tr><td>1088</td><td>1591</td><td>1</td><td>974936438</td><td>2.3341706</td></tr><tr><td>392</td><td>1645</td><td>4</td><td>976550402</td><td>3.134005</td></tr><tr><td>392</td><td>1959</td><td>4</td><td>976552172</td><td>3.2426915</td></tr><tr><td>858</td><td>1580</td><td>3</td><td>975345152</td><td>3.9262373</td></tr><tr><td>897</td><td>1645</td><td>3</td><td>975222773</td><td>3.2163181</td></tr><tr><td>31</td><td>2366</td><td>5</td><td>978120364</td><td>3.6254513</td></tr><tr><td>516</td><td>1580</td><td>3</td><td>976280139</td><td>3.0079026</td></tr><tr><td>1139</td><td>1645</td><td>3</td><td>974877900</td><td>3.4581625</td></tr><tr><td>137</td><td>1645</td><td>4</td><td>1000868305</td><td>3.5603244</td></tr><tr><td>251</td><td>1580</td><td>4</td><td>976715892</td><td>3.5030975</